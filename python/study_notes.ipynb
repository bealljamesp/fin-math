# %% [markdown]
# |Feature|`assert`|`try/except/raise`|
# |-----|--------|------------------|
# | Intent | Catch developer bugs | Catch user/system errors |
# |Target | Checking for conditions that should be impossible | Checking this out of your control |
# | Recoverability | Not recoverable, halt program and fix | Recoverable, ask the user to try again |

# %%
# 1. Activate your custom environment
conda activate code-python

# 2. Install the bridge package inside it
conda install ipykernel

# 3. Register this specific environment into Jupyter's browser menu
python -m ipykernel install --user --name=code-python --display-name "Python (code-python)"
