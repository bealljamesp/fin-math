# %%
Absorption costing (or "full costing") is a managerial accounting method that captures all costs associated with manufacturing a product. It includes direct materials, direct labor, variable overhead, and fixed overhead. This approach is mandatory for external financial reporting under GAAP and IFRS.The CalculationTo find the absorption cost per unit, you sum all manufacturing costs and divide by the total number of units produced.\(\text{Absorption\ Cost\ Per\ Unit}=\frac{\text{Direct\ Materials}+\text{Direct\ Labor}+\text{Variable\ Overhead}+\text{Fixed\ Overhead}}{\text{Total\ Units\ Produced}}\)The 4 Main ComponentsDirect Materials: Raw materials used directly in the creation of the product.Direct Labor: Wages for workers directly involved in manufacturing the goods.Variable Manufacturing Overhead: Production costs that fluctuate with output (e.g., electricity for factory machines).Fixed Manufacturing Overhead: Constant expenses that remain the same regardless of production volume (e.g., factory rent, machinery depreciation, insurance).Pros and ConsAdvantage (Compliance): Satisfies external reporting standards by matching the costs of production with the revenues generated when those items are sold.Advantage (Valuation): Provides a more realistic, comprehensive look at the total resources required to bring a product to market.Drawback (Incentive to Overproduce): Because fixed overhead is spread across units, producing a larger volume artificially lowers the per-unit cost. This can result in inflated profits on the income statement if unsold goods sit in inventory.
